# %% [markdown]
# # Birth Number in Korea
# Many press or social expert estimates that Low birth rate and aging problem will be critical.
# To understand trends of Low birth, try to visualize trends and prove that is true or not.
#
# ## Data from kosis
# http://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=INH_1B81A01&vw_cd=MT_GTITLE01&list_id=101&seqNo=&lang_mode=ko&language=kor&obj_var_id=&itm_id=&conn_path=MT_GTITLE01
#
# ### Learning from todaycode
# https://www.youtube.com/watch?v=traVslTwiHM

# %%
import pandas as pd
import numpy as np

# %%
df_kosis = pd.read_csv('./data/data_kosis_20200704131824.csv', encoding='cp949')
df_kosis.shape
# Out:
# (19, 793)

# %%
df_kosis.head()
# Out:
#     시군구별 1997. 01 1997. 01.1 1997. 01.2 1997. 02 1997. 02.1 1997. 02.2  \
# 0   시군구별    계 (명)     남자 (명)     여자 (명)    계 (명)     남자 (명)     여자 (명)
# 1     전국    63268      33266      30002    58144      30086      28058
# 2  서울특별시    13205       6886       6319    12239       6224       6015
# 3  부산광역시     4201       2260       1941     3910       2104       1806
# 4  대구광역시     3345       1764       1581     2994       1608       1386
#
#   1997. 03 1997. 03.1 1997. 03.2  ... 2018. 09.2 2018. 10 2018. 10.1  \
# 0    계 (명)     남자 (명)     여자 (명)  ...     여자 (명)    계 (명)     남자 (명)
# 1    62160      32333      29827  ...      12557    26474      13601
# 2    13358       6947       6411  ...       2247     4689       2466
# 3     4304       2234       2070  ...        713     1525        792
# 4     3337       1815       1522  ...        537     1151        587
#
#   2018. 10.2 2018. 11 2018. 11.1 2018. 11.2 2018. 12 2018. 12.1 2018. 12.2
# ...

# %% [markdown]
# #### To display all of columns in table, we can set as below.

# %%
pd.options.display.max_columns = df_kosis.shape[1]

# %%
df_kosis.head()
# Out:
#     시군구별 1997. 01 1997. 01.1 1997. 01.2 1997. 02 1997. 02.1 1997. 02.2  \
# 0   시군구별    계 (명)     남자 (명)     여자 (명)    계 (명)     남자 (명)     여자 (명)
# 1     전국    63268      33266      30002    58144      30086      28058
# 2  서울특별시    13205       6886       6319    12239       6224       6015
# 3  부산광역시     4201       2260       1941     3910       2104       1806
# 4  대구광역시     3345       1764       1581     2994       1608       1386
#
#   1997. 03 1997. 03.1 1997. 03.2 1997. 04 1997. 04.1 1997. 04.2 1997. 05  \
# 0    계 (명)     남자 (명)     여자 (명)    계 (명)     남자 (명)     여자 (명)    계 (명)
# 1    62160      32333      29827    56949      29449      27500    55270
# 2    13358       6947       6411    12146       6152       5994    11637
# 3     4304       2234       2070     3872       2026       1846     3826
# 4     3337       1815       1522     3025       1603       1422     2855
#
#   1997. 05.1 1997. 05.2 1997. 06 1997. 06.1 1997. 06.2 1997. 07 1997. 07.1  \
# ...

# %% [markdown]
# ### Tidy Data
# https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html

# %%
df = df_kosis.melt(id_vars="시군구별")
df.head()
# Out:
#     시군구별  variable  value
# 0   시군구별  1997. 01  계 (명)
# 1     전국  1997. 01  63268
# 2  서울특별시  1997. 01  13205
# 3  부산광역시  1997. 01   4201
# 4  대구광역시  1997. 01   3345

# %%
df["시군구별"].unique()
# Out:
# array(['시군구별', '전국', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시',
#        '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도',
#        '경상북도', '경상남도', '제주특별자치도'], dtype=object)

# %%
df[df["시군구별"]=='시군구별'].head()
# Out:
#     시군구별    variable   value
# 0   시군구별    1997. 01   계 (명)
# 19  시군구별  1997. 01.1  남자 (명)
# 38  시군구별  1997. 01.2  여자 (명)
# 57  시군구별    1997. 02   계 (명)
# 76  시군구별  1997. 02.1  남자 (명)

# %%
# Remove useless columns
df[df["시군구별"]!='시군구별'].head()
# Out:
#     시군구별  variable  value
# 1     전국  1997. 01  63268
# 2  서울특별시  1997. 01  13205
# 3  부산광역시  1997. 01   4201
# 4  대구광역시  1997. 01   3345
# 5  인천광역시  1997. 01   3646

# %%
print(df.shape)
df = df[df["시군구별"]!='시군구별'].copy()
print(df.shape)
# Out:
# (15048, 3)
# (14256, 3)

# %%
df.head()
# Out:
#     시군구별  variable  value
# 1     전국  1997. 01  63268
# 2  서울특별시  1997. 01  13205
# 3  부산광역시  1997. 01   4201
# 4  대구광역시  1997. 01   3345
# 5  인천광역시  1997. 01   3646

# %%
df["variable"]
# for eaxample, 1997 - year
#               01 - month
#               1 or 2 - male or female
# Out:
# 1          1997. 01
# 2          1997. 01
# 3          1997. 01
# 4          1997. 01
# 5          1997. 01
#             ...
# 15043    2018. 12.2
# 15044    2018. 12.2
# 15045    2018. 12.2
# 15046    2018. 12.2
# 15047    2018. 12.2
# Name: variable, Length: 14256, dtype: object

# %%
# split Variable by '.'
df["variable"].str.split('.', expand=True)
# Out:
#           0    1     2
# 1      1997   01  None
# 2      1997   01  None
# 3      1997   01  None
# 4      1997   01  None
# 5      1997   01  None
# ...     ...  ...   ...
# 15043  2018   12     2
# 15044  2018   12     2
# 15045  2018   12     2
# 15046  2018   12     2
# 15047  2018   12     2
#
# [14256 rows x 3 columns]

# %%
df['year'] = df['variable'].str.split('.', expand=True)[0]
df.head()
# Out:
#     시군구별  variable  value  year
# 1     전국  1997. 01  63268  1997
# 2  서울특별시  1997. 01  13205  1997
# 3  부산광역시  1997. 01   4201  1997
# 4  대구광역시  1997. 01   3345  1997
# 5  인천광역시  1997. 01   3646  1997

# %%
df['month'] = df['variable'].str.split('.', expand=True)[1]
df.head()
# Out:
#     시군구별  variable  value  year month
# 1     전국  1997. 01  63268  1997    01
# 2  서울특별시  1997. 01  13205  1997    01
# 3  부산광역시  1997. 01   4201  1997    01
# 4  대구광역시  1997. 01   3345  1997    01
# 5  인천광역시  1997. 01   3646  1997    01

# %%
df['gender'] = df['variable'].str.split('.', expand=True)[2]
df.tail()
# Out:
#           시군구별    variable value  year month gender
# 15043     전라북도  2018. 12.2   312  2018    12      2
# 15044     전라남도  2018. 12.2   392  2018    12      2
# 15045     경상북도  2018. 12.2   537  2018    12      2
# 15046     경상남도  2018. 12.2   696  2018    12      2
# 15047  제주특별자치도  2018. 12.2   159  2018    12      2

# %%
df['gender'].unique()
# Out:
# array([None, '1', '2'], dtype=object)

# %%
# fill 0(total) in gender None value
df['gender'] = df['gender'].fillna('0')
df.head(10)
# Out:
#        시군구별  variable  value  year month gender
# 1        전국  1997. 01  63268  1997    01      0
# 2     서울특별시  1997. 01  13205  1997    01      0
# 3     부산광역시  1997. 01   4201  1997    01      0
# 4     대구광역시  1997. 01   3345  1997    01      0
# 5     인천광역시  1997. 01   3646  1997    01      0
# 6     광주광역시  1997. 01   2166  1997    01      0
# 7     대전광역시  1997. 01   2003  1997    01      0
# 8     울산광역시  1997. 01   1754  1997    01      0
# 9   세종특별자치시  1997. 01      -  1997    01      0
# 10      경기도  1997. 01  13440  1997    01      0

# %%
# But I want to change word not number in gender columns,
df['gender'] = df['gender'].replace('0', 'total').replace('1', 'male').replace('2', 'female')

# %%
df.head(10)
# Out:
#        시군구별  variable  value  year month gender
# 1        전국  1997. 01  63268  1997    01  total
# 2     서울특별시  1997. 01  13205  1997    01  total
# 3     부산광역시  1997. 01   4201  1997    01  total
# 4     대구광역시  1997. 01   3345  1997    01  total
# 5     인천광역시  1997. 01   3646  1997    01  total
# 6     광주광역시  1997. 01   2166  1997    01  total
# 7     대전광역시  1997. 01   2003  1997    01  total
# 8     울산광역시  1997. 01   1754  1997    01  total
# 9   세종특별자치시  1997. 01      -  1997    01  total
# 10      경기도  1997. 01  13440  1997    01  total

# %%
df.tail(10)
# Out:
#           시군구별    variable value  year month  gender
# 15038  세종특별자치시  2018. 12.2   137  2018    12  female
# 15039      경기도  2018. 12.2  3010  2018    12  female
# 15040      강원도  2018. 12.2   288  2018    12  female
# 15041     충청북도  2018. 12.2   342  2018    12  female
# 15042     충청남도  2018. 12.2   481  2018    12  female
# 15043     전라북도  2018. 12.2   312  2018    12  female
# 15044     전라남도  2018. 12.2   392  2018    12  female
# 15045     경상북도  2018. 12.2   537  2018    12  female
# 15046     경상남도  2018. 12.2   696  2018    12  female
# 15047  제주특별자치도  2018. 12.2   159  2018    12  female

# %%
df['gender'].value_counts()
# Out:
# female    4752
# total     4752
# male      4752
# Name: gender, dtype: int64

# %%
df.rename(columns={'variable':'period', 'value':'amount'}, inplace=True)
df.head(10)
# Out:
#        시군구별    period amount  year month gender
# 1        전국  1997. 01  63268  1997    01  total
# 2     서울특별시  1997. 01  13205  1997    01  total
# 3     부산광역시  1997. 01   4201  1997    01  total
# 4     대구광역시  1997. 01   3345  1997    01  total
# 5     인천광역시  1997. 01   3646  1997    01  total
# 6     광주광역시  1997. 01   2166  1997    01  total
# 7     대전광역시  1997. 01   2003  1997    01  total
# 8     울산광역시  1997. 01   1754  1997    01  total
# 9   세종특별자치시  1997. 01      -  1997    01  total
# 10      경기도  1997. 01  13440  1997    01  total

# %% [markdown]
# ## Start to Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14256 entries, 1 to 15047
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구별    14256 non-null  object
#  1   period  14256 non-null  object
#  2   amount  14256 non-null  object
#  3   year    14256 non-null  object
#  4   month   14256 non-null  object
#  5   gender  14256 non-null  object
# dtypes: object(6)
# memory usage: 779.6+ KB

# %%
df['amount'] = df['amount'].replace('-', np.nan)
df['amount'] = df['amount'].astype(float)
df['amount'].describe()
# Out:
# count    13716.000000
# mean      3129.701079
# std       6776.118929
# min         30.000000
# 25%        653.000000
# 50%       1065.000000
# 75%       1976.250000
# max      63268.000000
# Name: amount, dtype: float64

# %%
# all cities & gender equal total indexing
df_all = df[(df['시군구별'] == '전국') & (df['gender'] == 'total')]
df_all.head()
# Out:
#     시군구별    period   amount  year month gender
# 1     전국  1997. 01  63268.0  1997    01  total
# 58    전국  1997. 02  58144.0  1997    02  total
# 115   전국  1997. 03  62160.0  1997    03  total
# 172   전국  1997. 04  56949.0  1997    04  total
# 229   전국  1997. 05  55270.0  1997    05  total

# %%
# we need only year, month amount columns.
df_all = df_all[['year', 'month', 'amount']].copy()
df_all
# Out:
#        year month   amount
# 1      1997    01  63268.0
# 58     1997    02  58144.0
# 115    1997    03  62160.0
# 172    1997    04  56949.0
# 229    1997    05  55270.0
# ...     ...   ...      ...
# 14764  2018    08  27381.0
# 14821  2018    09  26066.0
# 14878  2018    10  26474.0
# 14935  2018    11  25301.0
# 14992  2018    12  22767.0
#
# [264 rows x 3 columns]

# %%
# if you need font set for korean or japanese,
import matplotlib.pyplot as plt
# plt.rc("font", family="Malgun Gothic") for win
plt.rc("font", family="AppleGothic" ) #for mac
df_all.set_index(['year', 'month']).plot(figsize=(15,4))

# %%
df_all[-36:].set_index(['year', 'month']).plot.bar(figsize=(15,4))

# %%
# Seaborn
import seaborn as sns

# %%
df_all
# Out:
#        year month   amount
# 1      1997    01  63268.0
# 58     1997    02  58144.0
# 115    1997    03  62160.0
# 172    1997    04  56949.0
# 229    1997    05  55270.0
# ...     ...   ...      ...
# 14764  2018    08  27381.0
# 14821  2018    09  26066.0
# 14878  2018    10  26474.0
# 14935  2018    11  25301.0
# 14992  2018    12  22767.0
#
# [264 rows x 3 columns]

# %%
plt.figure(figsize = (15,4))
sns.lineplot(data=df_all, x='year', y='amount')
# ci : Confidence Inteval(신뢰구간) 95%

# %%
# express as Month on lineplot
plt.figure(figsize = (15,4))
df_all['month'] = df_all['month'].astype(int)
sns.lineplot(data=df_all, x='year', y='amount',ci=None, hue='month')

# %%
plt.figure(figsize = (15,4))
sns.barplot(data=df_all, x='year', y='amount')

# %%
df
# Out:
#           시군구별      period   amount  year month  gender
# 1           전국    1997. 01  63268.0  1997    01   total
# 2        서울특별시    1997. 01  13205.0  1997    01   total
# 3        부산광역시    1997. 01   4201.0  1997    01   total
# 4        대구광역시    1997. 01   3345.0  1997    01   total
# 5        인천광역시    1997. 01   3646.0  1997    01   total
# ...        ...         ...      ...   ...   ...     ...
# 15043     전라북도  2018. 12.2    312.0  2018    12  female
# 15044     전라남도  2018. 12.2    392.0  2018    12  female
# 15045     경상북도  2018. 12.2    537.0  2018    12  female
# 15046     경상남도  2018. 12.2    696.0  2018    12  female
# 15047  제주특별자치도  2018. 12.2    159.0  2018    12  female
#
# [14256 rows x 6 columns]

# %% [markdown]
# I want to compare with each city.
# Then, I can understand which city birth rate is high.
# So I remove the data, sum of all cities.

# %%
df_local = df[df['시군구별'] != '전국']
df_local.head()
# Out:
#     시군구별    period   amount  year month gender
# 2  서울특별시  1997. 01  13205.0  1997    01  total
# 3  부산광역시  1997. 01   4201.0  1997    01  total
# 4  대구광역시  1997. 01   3345.0  1997    01  total
# 5  인천광역시  1997. 01   3646.0  1997    01  total
# 6  광주광역시  1997. 01   2166.0  1997    01  total

# %%
plt.figure(figsize=(15,4))
sns.pointplot(data=df_local, x="year", y="amount", hue="gender")

# %%
df_local_all = df_local[df_local['gender'] == 'total']
df_local_all
# Out:
#           시군구별    period   amount  year month gender
# 2        서울특별시  1997. 01  13205.0  1997    01  total
# 3        부산광역시  1997. 01   4201.0  1997    01  total
# 4        대구광역시  1997. 01   3345.0  1997    01  total
# 5        인천광역시  1997. 01   3646.0  1997    01  total
# 6        광주광역시  1997. 01   2166.0  1997    01  total
# ...        ...       ...      ...   ...   ...    ...
# 15005     전라북도  2018. 12    640.0  2018    12  total
# 15006     전라남도  2018. 12    790.0  2018    12  total
# 15007     경상북도  2018. 12   1159.0  2018    12  total
# 15008     경상남도  2018. 12   1399.0  2018    12  total
# 15009  제주특별자치도  2018. 12    330.0  2018    12  total
#
# [4488 rows x 6 columns]

# %%
plt.figure(figsize=(14,4))
sns.pointplot(data=df_local_all, x='year', y='amount')

# %%
plt.figure(figsize=(14,4))
sns.pointplot(data=df_local_all, x='year', y='amount', hue='시군구별', ci=None)
# draw regend out of graph
plt.legend(loc='center right', bbox_to_anchor=(1.15, 0.5), ncol=1)

# %%
df_local_2 = df_local_all[df_local_all["시군구별"].isin(['서울특별시', '경기도', '세종특별자치시'])]
df_local_2
# Out:
#           시군구별    period   amount  year month gender
# 2        서울특별시  1997. 01  13205.0  1997    01  total
# 9      세종특별자치시  1997. 01      NaN  1997    01  total
# 10         경기도  1997. 01  13440.0  1997    01  total
# 59       서울특별시  1997. 02  12239.0  1997    02  total
# 66     세종특별자치시  1997. 02      NaN  1997    02  total
# ...        ...       ...      ...   ...   ...    ...
# 14943  세종특별자치시  2018. 11    337.0  2018    11  total
# 14944      경기도  2018. 11   6763.0  2018    11  total
# 14993    서울특별시  2018. 12   4110.0  2018    12  total
# 15000  세종특별자치시  2018. 12    285.0  2018    12  total
# 15001      경기도  2018. 12   6226.0  2018    12  total
#
# [792 rows x 6 columns]

# %%
plt.figure(figsize=(14,4))
sns.pointplot(data=df_local_2, x='year', y='amount', ci=None, hue='시군구별')

# %%
df_sj = df[df["시군구별"] == "세종특별자치시"].dropna(how="any")
df_sj
# Out:
#           시군구별      period  amount  year month  gender
# 10269  세종특별자치시    2012. 01    73.0  2012    01   total
# 10288  세종특별자치시  2012. 01.1    38.0  2012    01    male
# 10307  세종특별자치시  2012. 01.2    35.0  2012    01  female
# 10326  세종특별자치시    2012. 02    74.0  2012    02   total
# 10345  세종특별자치시  2012. 02.1    43.0  2012    02    male
# ...        ...         ...     ...   ...   ...     ...
# 14962  세종특별자치시  2018. 11.1   188.0  2018    11    male
# 14981  세종특별자치시  2018. 11.2   149.0  2018    11  female
# 15000  세종특별자치시    2018. 12   285.0  2018    12   total
# 15019  세종특별자치시  2018. 12.1   148.0  2018    12    male
# 15038  세종특별자치시  2018. 12.2   137.0  2018    12  female
#
# [252 rows x 6 columns]

# %%
sns.pointplot(data=df_sj, x='year', y='amount', ci=None, estimator=pd.np.sum)
# Out:
# /opt/anaconda3/envs/PythonDataScienceExam/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """Entry point for launching an IPython kernel.
